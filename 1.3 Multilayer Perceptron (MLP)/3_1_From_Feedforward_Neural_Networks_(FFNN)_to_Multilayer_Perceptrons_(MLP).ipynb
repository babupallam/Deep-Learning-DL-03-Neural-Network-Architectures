# %% [markdown]
# <a href="https://colab.research.google.com/github/babupallam/Deep-Learning-DL-03-Neural-Network-Architectures/blob/main/3_1_From_Feedforward_Neural_Networks_(FFNN)_to_Multilayer_Perceptrons_(MLP).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3.1 From Feedforward Neural Networks (FFNN) to Multilayer Perceptrons (MLP)

# %% [markdown]
# ## 1.Introduction to Feedforward Neural Networks (FFNN):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Limitations of Basic FFNNs:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. Movement Towards MLP:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## How to convert FFNN to MLP?

# %% [markdown]
# ![image.png](data:image/png;base64,...)
