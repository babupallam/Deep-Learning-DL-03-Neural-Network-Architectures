# %% [markdown]
# <a href="https://colab.research.google.com/github/babupallam/Deep-Learning-DL-03-Neural-Network-Architectures/blob/main/3_9_From_MLP_to_Convolutional_Neural_Networks_(CNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Limitations of MLP (Multilayer Perceptron)

# %% [markdown]
# Multilayer Perceptron (MLP) is a basic type of feedforward neural network, primarily used for tasks such as classification and regression. While MLPs have shown effectiveness in various applications, they suffer from several limitations, especially when it comes to handling complex data like images.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Problems in MLP for Image Processing

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. Solution: Convolutional Neural Networks (CNN)

# %% [markdown]
# Convolutional Neural Networks (CNNs) were introduced as a solution to the above limitations, especially for handling image data. CNNs are designed to recognize and exploit the spatial structure inherent in images through convolutional layers.

# %% [markdown]
# ## Key Innovations in CNN to Solve MLP Problems:

# %% [markdown]
# ### 1.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 4.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 5.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. Advantages of CNN Over MLP

# %% [markdown]
# ![image.png](data:image/png;base64,...)
