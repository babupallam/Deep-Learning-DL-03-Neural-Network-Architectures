# %% [markdown]
# <a href="https://colab.research.google.com/github/babupallam/Deep-Learning-DL-03-Neural-Network-Architectures/blob/main/1_1_Perceptron_Concepts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.1 Perceptron

# %% [markdown]
# ## Concepts

# %% [markdown]
# #### 1.1.1 Single-layer Neural Network:

# %% [markdown]
# A single-layer neural network refers to a neural network with just one layer of neurons between the input and the output. The perceptron is the most basic form of such a neural network and serves as an introduction to the more complex architectures of neural networks. Below, we’ll break down the structure and functionality of a single-layer neural network, specifically focusing on the perceptron.

# %% [markdown]
# ##### 1.Architecture of a Perceptron (Single-layer Neural Network)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##### 2.Mathematical Representation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##### 3.Key Idea Behind the Perceptron

# %% [markdown]
# ###### 1. **Input Layer**
#    - **Input Nodes (x1, x2, x3, …)**: These represent the features or data points that we’re giving to the perceptron. For example, if we are trying to classify images of apples and oranges, the input nodes could be various features of the image (like color, texture, size, etc.).
#    - Each input node corresponds to one feature, and they will be used to generate the output of the perceptron.

# %% [markdown]
# ###### 2. **Weights (w1, w2, w3, …)**
#    - **Weights** are like dials on a machine, tuning how much importance each input has. If a certain input is very important for determining the output, its weight will be large. If an input is not very important, its weight will be small or even negative.
#    - In the diagram, each input is connected to the next layer by a line that represents the weight.
#
#    - **Example**: If you’re determining whether an image contains an apple, the color red might be a strong indicator, so the input for color will have a higher weight. Other factors, like shape, might have lower weights if they are less important for the decision.

# %% [markdown]
# ###### 3. **Summation Node (Σ)**
#    - This node collects all the inputs and their corresponding weights. In this step, we multiply each input by its weight and add them all together.
#
#   ![image.png](data:image/png;base64,...)
#
#    - This is where the perceptron calculates a weighted sum of the inputs to decide if the final result should be positive (1) or negative (0).

# %% [markdown]
# ###### 4. **Bias Term (b)**
#    - The **bias** is like an extra input that helps the perceptron make decisions more easily by shifting the summation result. It helps the perceptron move the decision boundary (the line or plane that separates the classes).
#    - In simple terms, it’s an added flexibility to help the perceptron classify data better when it’s hard to separate by a straight line.
#
#    - **Example**: If you think of the decision boundary as a line that divides apples and oranges, the bias helps to move this line left or right, improving the accuracy of classification.

# %% [markdown]
# ###### 5. **Activation Function (Step Function)**
#    - After the summation node and bias, the total value is passed through an **activation function**.
#    - In the perceptron, we typically use the **step function**, which looks at the result of the summation and makes a decision:
#      - If the result is greater than or equal to a certain threshold (often zero), the perceptron outputs a 1 (indicating one class, like "apple").
#      - If the result is less than the threshold, it outputs a 0 (indicating the other class, like "orange").
#
#    ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### 6. **Output (y)**
#    - The output of the perceptron is the final decision, which is either a 1 (yes, belongs to class 1) or a 0 (no, belongs to class 2).
#    - In our apple vs. orange example, the output would tell us whether the image is classified as an apple (1) or an orange (0).

# %% [markdown]
# Note: **Why These steps are important**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  **Example 1: Whether the image is cat?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example 2: Weather Predition (Rain or No Rain)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example 3: Spam Email Detection**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example 4: Fruit Classification (Apple or Orange)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example 5: Loan Approval (Approved or Not Approved)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example 6: Disease Diagnosis (Positive or Negative)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##### 4.Activation Function in Detail (Step Function)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##### 5.Decision Boundary and Linear Separability

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##### 6.Training the Perceptron

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### 1.Initialization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### 2.Forward Pass (Prediction)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### 3.Loss Calculation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### 4.Weight and Bias Update (Perceptron Learning Rule)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### 5.Iterating Over Training Data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### 6.Stopping Criteria

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### 7.Learning Rate and Convergence

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### Example 1: Example 1: Perceptron Training for AND Gate

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### Example 2: Spam Email Classification

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##### 7.Why is the Perceptron Important?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# #### 1.1.2 Binary Classification:

# %% [markdown]
#  - A perceptron is typically used for tasks that have two output classes (e.g., True/False, Yes/No, 0/1). It’s essentially a linear classifier, meaning it tries to separate data points with a straight line (or a hyperplane in higher dimensions).

# %% [markdown]
# ---

# %% [markdown]
# #### 1.1.3 Linear Separability:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example for nonlinear seperability
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# #### 1.1.4 Activation Function (Step Function):

# %% [markdown]
# The step function is a simple activation function. If the input sum exceeds a threshold, it outputs a 1 (positive class); otherwise, it outputs a 0 (negative class). This means the perceptron’s decision is binary and doesn’t output probabilities.

# %% [markdown]
# ---

# %% [markdown]
# ## Observations

# %% [markdown]
# #### How does the perceptron handle linearly separable data?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Compare Perceptron with Other Machine Learning Algorithms

# %% [markdown]
# ##### Comparison of Perceptron with Other Machine Learning Algorithms
#
# | **Feature/Aspect**                | **Perceptron**                            | **Logistic Regression**                  | **Support Vector Machine (SVM)**       | **Decision Tree**                          | **k-Nearest Neighbors (k-NN)**            |
# |-----------------------------------|-------------------------------------------|------------------------------------------|-----------------------------------------|-------------------------------------------|-------------------------------------------|
# | **Type of Algorithm**             | Linear Classifier                         | Linear Classifier                        | Linear/Non-linear Classifier (with kernel trick) | Non-linear Classifier                     | Non-parametric Algorithm                 |
# | **Decision Boundary**             | Linear (straight line or hyperplane)       | Linear (hyperplane)                      | Linear or Non-linear (with kernel trick) | Non-linear (step-like boundaries)         | No explicit boundary, based on neighbors |
# | **Output**                        | Binary (0/1)                              | Probability (0 to 1)                     | Binary (0/1, or multi-class with extensions) | Discrete class labels (binary or multi-class) | Class label, based on majority voting   |
# | **Activation Function**           | Step function (0 or 1)                    | Sigmoid function (0 to 1)                | Hinge loss (maximizing margin)          | No activation function                     | No activation function                   |
# | **Linear Separability**           | Can only handle linearly separable data    | Can handle linearly separable data       | Can handle both linear and non-linear separable data | Works with both linear and non-linear data | Non-linear data (no assumption of linearity) |
# | **Learning Method**               | Gradient Descent (Perceptron Learning Rule)| Gradient Descent                         | Quadratic Programming                   | Greedy search (splitting data)             | No learning, stores the training data    |
# | **Training Complexity**           | \( O(m \times n) \)                       | \( O(m \times n) \)                      | \( O(m^2 \times n) \)                   | \( O(m \times n \log m) \)                | \( O(m \times n) \)                      |
# | **Convergence**                   | Converges for linearly separable data      | Converges for both separable and non-separable data | Converges for both linearly separable and non-separable data | May overfit if not pruned                 | No convergence, only based on majority voting |
# | **Regularization**                | No regularization                         | Yes (L1/L2 regularization)               | Yes (with soft margin, C parameter)     | Pruning and max-depth control              | None                                     |
# | **Ability to Handle Noisy Data**  | Sensitive to noise                        | More robust due to probabilistic output  | Robust with the soft margin (C parameter) | Sensitive to noise and overfitting        | Sensitive to noise                       |
# | **Multi-class Extension**         | One-vs-All method                         | Multi-class inherently supported         | One-vs-All, One-vs-One                  | Inherently supports multi-class           | Inherently supports multi-class          |
# | **Hyperparameters**               | Learning rate                             | Regularization strength (L1/L2)          | C (soft margin), kernel type            | Max depth, pruning                         | k (number of neighbors)                  |
# | **Advantages**                    | Simple, fast for linearly separable data   | Outputs probabilities, interpretable     | Works well for complex decision boundaries | Intuitive, easy to visualize              | Simple, no training required             |
# | **Limitations**                   | Can only solve linearly separable problems | Assumes linear decision boundary         | High complexity for large datasets, requires kernel choice | Prone to overfitting, requires pruning    | Slow for large datasets, requires distance calculation |

# %% [markdown]
# ##### Comparison of Perceptron with Algorithms Handling Non-Linearity
#
# | **Feature/Aspect**                | **Perceptron**                            | **Multilayer Perceptron (MLP)**          | **Random Forest**                       | **Naive Bayes**                           | **Gradient Boosting**                    |
# |-----------------------------------|-------------------------------------------|------------------------------------------|-----------------------------------------|-------------------------------------------|-------------------------------------------|
# | **Type of Algorithm**             | Linear Classifier                         | Neural Network with Hidden Layers        | Ensemble of Decision Trees              | Probabilistic Classifier                  | Ensemble of Weak Learners (Trees)        |
# | **Decision Boundary**             | Linear                                    | Non-linear (due to hidden layers)        | Non-linear (forest of trees)            | Linear boundary based on feature independence assumptions | Non-linear (boosting trees)              |
# | **Non-linear Problems**           | Cannot handle non-linearity               | Can handle non-linearity with hidden layers | Can handle non-linear problems          | Assumes feature independence, struggles with non-linearity | Can handle complex non-linear problems   |
# | **Learning Method**               | Perceptron Learning Rule                  | Backpropagation                          | Bagging (random sampling)               | Maximum Likelihood Estimation             | Boosting (sequential learning)           |
# | **Training Complexity**           | \( O(m \times n) \)                       | Higher than Perceptron due to hidden layers and backpropagation | \( O(m \times n \log m) \)               | \( O(m \times n) \)                      | \( O(m \times n \log m) \)              |
# | **Regularization**                | No regularization                         | Yes (L1/L2, dropout)                     | No, but can be controlled with tree depth | No regularization                         | Yes (L1/L2 or learning rate)             |
# | **Convergence**                   | Only for linearly separable problems       | Can converge for both linear and non-linear problems | May overfit if not controlled            | Can converge with independent features   | Slow convergence but great accuracy      |
# | **Ability to Handle Noisy Data**  | Sensitive to noise                        | More robust due to multiple layers       | Robust, but sensitive to overfitting    | Sensitive to noisy data                   | More robust, but sensitive to overfitting|
# | **Multi-class Extension**         | One-vs-All                                | Inherently supports multi-class          | Inherently supports multi-class          | Inherently supports multi-class           | Inherently supports multi-class          |
# | **Advantages**                    | Simple, fast for linearly separable data   | Can learn complex, non-linear decision boundaries | Reduces overfitting, good for small data sets | Fast and interpretable, low computational cost | High accuracy, handles complex data well |
# | **Limitations**                   | Cannot solve non-linear problems          | Computationally expensive, prone to overfitting without regularization | Slower with large datasets, prone to overfitting | Assumes feature independence, not suitable for complex problems | Computationally expensive, slower to train |

# %% [markdown]
# #### What happens when data is not linearly separable, such as in the XOR problem?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### How does the step activation function impact the perceptron’s ability to generalize?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Why step function is the only activation function used in perceptron

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### How does the learning rate affect the performance of a perceptron?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### What limitations does a single-layer perceptron have compared to a multi-layer network?

# %% [markdown]
# | **Aspect**                      | **Single-Layer Perceptron**                      | **Multi-Layer Network (e.g., MLP)**             |
# |----------------------------------|--------------------------------------------------|-------------------------------------------------|
# | **Linear vs Non-Linear Problems** | Can only solve **linearly separable** problems.  | Can solve **non-linear** problems (e.g., XOR).  |
# | **Architecture**                 | Has only one layer of weights between input and output. | Has multiple layers (input, hidden, output) which introduce non-linearity and complexity. |
# | **Expressive Power**             | **Limited**: Cannot model complex decision boundaries. | **More powerful**: Can approximate any function with enough hidden units (Universal Approximation Theorem). |
# | **Activation Functions**         | Uses a **step function** (or sometimes a linear function) which limits flexibility. | Uses advanced non-linear functions like **ReLU, Sigmoid, Tanh**, which allow the network to learn more complex patterns. |
# | **Ability to Handle XOR Problem** | **Fails** to solve XOR (non-linear) problems, as no linear boundary can separate the XOR output classes. | **Can solve** XOR and other non-linearly separable problems by introducing hidden layers and non-linear activations. |
# | **Feature Learning**             | Cannot learn features or representations beyond a linear combination of inputs. | Can learn **hierarchical features**, where each layer transforms the input features into higher-level abstractions. |
# | **Decision Boundaries**          | Forms **linear decision boundaries**, which limits its application. | Can form **non-linear decision boundaries**, making it more versatile. |
# | **Learning Capacity**            | Has a **low capacity** for learning complex patterns due to its linear nature. | Has **high capacity** to learn complex patterns, which increases with the number of layers and neurons. |
# | **Vanishing Gradient**           | Not an issue as it only has one layer and simple activation functions. | Can experience **vanishing gradient** problems in deeper networks, especially with activations like sigmoid/tanh. However, modern techniques (e.g., ReLU) mitigate this. |
# | **Training Algorithm**           | Trained using the **perceptron learning rule**, a simple algorithm. | Trained using **backpropagation**, which allows for optimization over multiple layers. |
# | **Generalization**               | Generalizes poorly on non-linear data or noisy data. | Generalizes well on complex datasets, especially with regularization techniques (dropout, weight decay). |
# | **Overfitting**                  | Less prone to overfitting due to its simplicity, but this is due to its limited capacity. | More prone to overfitting, especially with too many layers, but this can be controlled using regularization. |
# | **Computational Complexity**     | Lower computational complexity due to fewer parameters. | Higher computational complexity due to more parameters in multiple layers. |
# | **Real-World Applications**      | Suitable for simple tasks such as basic binary classification on small datasets. | Suitable for more complex real-world tasks like image classification, natural language processing, and game-playing AI. |
#
# ---
#
# ===> Points Summarized:
#
# 1. **Inability to Solve Non-Linear Problems**:
#    - A single-layer perceptron can only handle linearly separable problems (e.g., AND gate), but it fails on non-linear tasks like XOR.
#    - Multi-layer networks, on the other hand, can handle non-linear problems by using non-linear activation functions and hidden layers.
#
# 2. **Limited Architecture**:
#    - A single-layer perceptron has only one layer, which limits its ability to capture complex patterns in data.
#    - Multi-layer networks have multiple hidden layers, which give them more representational power.
#
# 3. **Feature Learning**:
#    - Single-layer perceptrons can only combine inputs linearly, making them poor at learning useful features from data.
#    - Multi-layer networks can learn hierarchical, abstract features that are more useful for complex tasks like image recognition.
#
# 4. **Activation Function Limitations**:
#    - The perceptron typically uses a simple step function, which gives hard binary outputs, limiting its flexibility.
#    - Multi-layer networks use advanced activation functions like ReLU or sigmoid, which allow the model to output more nuanced and complex predictions.
#
# 5. **Learning Capacity**:
#    - Single-layer perceptrons have low learning capacity and cannot model complex relationships in data.
#    - Multi-layer networks, with their increased depth and non-linearity, have much higher learning capacities and can approximate complex functions.
#
# 6. **Training Algorithm**:
#    - Perceptrons are trained using a simple rule that adjusts weights based on the error. However, this rule doesn’t generalize well for deeper models.
#    - Multi-layer networks are trained using backpropagation, which is more sophisticated and allows the model to optimize over multiple layers.
#
# 7. **Generalization and Flexibility**:
#    - Single-layer perceptrons generalize poorly on complex or noisy data.
#    - Multi-layer networks, when properly regularized, generalize well even on challenging datasets.
#
# ---
#
# ==> Final Thought:
# While the single-layer perceptron is simple and useful for understanding the basics of neural networks, it’s very limited in its applications. Multi-layer networks introduce the necessary complexity (via hidden layers and non-linear activations) to handle real-world tasks effectively.

# %% [markdown]
# #### How does a perceptron’s training time scale with the size of the input data?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Can the perceptron be optimized to handle multi-class classification problems?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### What impact does noise in the data have on a perceptron’s accuracy?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### What is the computational complexity of training a perceptron?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### How does the perceptron algorithm compare with more complex models like SVM or Logistic Regression?

# %% [markdown]
# ---
#
# | **Aspect**                        | **Perceptron**                                      | **SVM (Support Vector Machine)**                          | **Logistic Regression**                                  |
# |------------------------------------|----------------------------------------------------|----------------------------------------------------------|---------------------------------------------------------|
# | **Type of Classifier**             | Linear classifier                                 | Linear classifier (can be extended to non-linear via kernels) | Linear classifier                                        |
# | **Output**                         | Binary (0 or 1)                                   | Binary (1 or -1) or multiclass with extensions            | Probability between 0 and 1 (continuous output)          |
# | **Learning Approach**              | Iterative weight update using the Perceptron rule | Finds the optimal hyperplane with the maximum margin      | Minimizes the cost function using gradient descent       |
# | **Objective**                      | Finds any hyperplane that separates the classes    | Finds the hyperplane that maximizes the margin between classes | Minimizes log-loss (cross-entropy)                       |
# | **Handling of Non-linear Data**    | Fails for non-linearly separable data              | Can handle non-linear data with kernels (e.g., RBF kernel) | Fails for non-linearly separable data                    |
# | **Robustness to Outliers**         | Sensitive to outliers                             | More robust due to margin maximization                    | Sensitive to outliers                                    |
# | **Activation Function**            | Step function (binary output)                     | No explicit activation function (focuses on margin maximization) | Sigmoid function (for probability estimation)            |
# | **Regularization**                 | No in-built regularization                        | Can use regularization (e.g., soft-margin SVM with slack variables) | Regularization through L2 (Ridge) or L1 (Lasso)          |
# | **Convergence Guarantee**          | Converges only if data is linearly separable      | Always converges (due to quadratic optimization)          | Always converges due to the nature of the log-loss       |
# | **Margin of Separation**           | No margin control                                 | Maximizes margin (distance between hyperplane and nearest points) | No margin concept                                        |
# | **Output Interpretability**        | Hard decision boundary (0 or 1)                   | Margin-based decision boundary (probabilistic with extensions) | Provides probabilities, easy to interpret                |
# | **Multiclass Classification**      | Can be adapted with One-vs-All (OvA) technique    | Uses One-vs-One or One-vs-All strategies                  | Directly handles multiclass classification with softmax  |
# | **Kernel Trick for Non-linear Data**| Not applicable                                    | Yes, can handle non-linear data through kernel methods    | Not applicable                                           |
# | **Speed and Complexity**           | Simple and fast                                   | More complex due to quadratic optimization                | Less complex than SVM, uses iterative optimization       |
# | **Generalization Ability**         | Limited generalization for complex data           | Strong generalization for both linear and non-linear data | Strong generalization, especially with regularization    |
#
# ---

# %% [markdown]
# :
