# %% [markdown]
# <a href="https://colab.research.google.com/github/babupallam/Deep-Learning-DL-03-Neural-Network-Architectures/blob/main/14_Creating_Deep_Learning_Foundations_(_Implementation_Perspective_of_Perceptron_in_Multi_layer_Networks).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 14 Creating Deep Learning Foundations ( Implementation Perspective of Perceptron in Multi-layer Networks)

# %% [markdown]
# ## 1. **What is a single-layer Perceptron, and what type of problems can it solve?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. **What is the major limitation of a Perceptron when dealing with complex problems?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. **How does stacking Perceptrons form a Multi-layer Perceptron (MLP)?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. **Why is the Multi-layer Perceptron (MLP) considered more powerful than a single Perceptron?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 5. **What is the role of multiple layers in the MLP compared to the single-layer Perceptron?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 6. **Why is a single-layer Perceptron insufficient for solving the XOR problem?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Explain how XOR makes the Perceptron fail, even though it has only two classes as output (0 or 1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 7. **What are linearly separable problems, and how does a Perceptron handle them?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 8. **What are non-linearly separable problems, and why can’t a single-layer Perceptron handle them?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 9. **How does the introduction of non-linear activation functions, like ReLU or Sigmoid, help in solving non-linear problems?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 10. **How does an MLP overcome the limitation of linear decision boundaries created by a single-layer Perceptron?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 11. **What is the purpose of hidden layers in an MLP, and how do they improve the model’s learning ability?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 12. **How do hidden layers help in learning complex, non-linear combinations of input features?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 13. **What are activation functions, and why are they crucial in multi-layer networks?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 14. **How does the ReLU activation function differ from Sigmoid in handling non-linearities?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 15. **Why is it necessary to apply a non-linear activation function after each hidden layer in the MLP?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 16. **What is backpropagation, and how does it extend the Perceptron learning rule?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Backpropagation is a generalization of the Perceptron learning rule that works for networks with multiple layers.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 17. **How does backpropagation use gradient descent to update weights in a multi-layer network?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 18. **What role does the chain rule of calculus play in backpropagation?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 19. **How does backpropagation calculate the error contribution of each layer during training?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 20. **Why is backpropagation considered a critical component in training deep neural networks?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 21. **Why is the MLP considered the foundation of modern deep learning architectures?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 22. **How has the introduction of optimization techniques like Adam and RMSprop improved the training of MLPs?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 23. **What are some key applications of deep learning models that are built on MLP principles?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 24. **How do deep learning models such as CNNs and RNNs build upon the basic concepts of MLP?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 25. **What makes deep learning models, which are essentially deeper MLPs, more capable of handling complex tasks compared to shallow models?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
